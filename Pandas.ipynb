# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroIsac564/data_science_aulas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# colab tem o pandas instalado mas esse é o código para instalar no terminal
# !pip install pandas

import pandas as pd

# %%
#Pegando a planilha e colocando na variavel 'pessoa'
pessoa = pd.read_excel('/content/teste.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-1c64a235859f> in <cell line: 0>()
#       1 #Pegando a planilha e colocando na variavel 'pessoa'
# ----> 2 pessoa = pd.read_excel('/content/teste.xlsx')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
type(pessoa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1de6601944df> in <cell line: 0>()
# ----> 1 type(pessoa)
#
# NameError: name 'pessoa' is not defined

# %% [markdown]
# # https://www.kaggle.com/datasets/cprete/covid19-open-datasets-for-brazil

# %%
# Leitura do arquivo
dados_covid = pd.read_excel('/content/HIST_PAINEL_COVIDBR_01jun2020.xlsx')
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
dados_covid #para mostrar todos os registros
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 142794  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142795  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142798  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados_covid.head() # '.head()' para  ver os cinco primeiros registros da tabela
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-26          9       210147125.0               1           0
# 1  2020-02-27          9       210147125.0               1           0
# 2  2020-02-28          9       210147125.0               1           0
# 3  2020-02-29          9       210147125.0               2           1
# 4  2020-03-01         10       210147125.0               2           0
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos
# ...

# %%
dados_covid.tail(10) # '.tail()' para  ver os ultimos registros da tabela, coloquei 10 para mostrar os 10 ultimos registros
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 142789  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142790  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142791  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142792  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142793  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142794  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142795  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142796  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142797  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 142798  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 142789        Brasília  2020-05-23         21         3015268.0
# ...

# %%
dados_covid.columns #para ver o nome das colunas
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos'],
#       dtype='object')

# %%
dados_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142799 entries, 0 to 142798
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   regiao                 142799 non-null  object
#  1   estado                 142702 non-null  object
#  2   municipio              139850 non-null  object
#  3   coduf                  142799 non-null  int64
#  4   codmun                 140536 non-null  float64
#  5   codRegiaoSaude         139850 non-null  float64
#  6   nomeRegiaoSaude        139850 non-null  object
#  7   data                   142799 non-null  object
#  8   semanaEpi              142799 non-null  int64
#  9   populacaoTCU2019       142113 non-null  float64
#  10  casosAcumulado         142799 non-null  int64
#  11  casosNovos             142799 non-null  int64
#  12  obitosAcumulado        142799 non-null  int64
#  13  obitosNovos            142799 non-null  int64
# ...

# %%
dados_covid[['regiao','municipio','estado','coduf']].head(10)
# Out:
#    regiao municipio estado  coduf
# 0  Brasil       NaN    NaN     76
# 1  Brasil       NaN    NaN     76
# 2  Brasil       NaN    NaN     76
# 3  Brasil       NaN    NaN     76
# 4  Brasil       NaN    NaN     76
# 5  Brasil       NaN    NaN     76
# 6  Brasil       NaN    NaN     76
# 7  Brasil       NaN    NaN     76
# 8  Brasil       NaN    NaN     76
# 9  Brasil       NaN    NaN     76

# %%
dados_covid[['casosNovos','obitosNovos']].describe()
# Out:
#           casosNovos    obitosNovos
# count  142799.000000  142799.000000
# mean       11.013817       0.634528
# std       248.500980      13.621583
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         1.000000       0.000000
# max     33274.000000    1188.000000

# %%
dados_covid.isna().sum()
# Out:
# regiao                        0
# estado                       97
# municipio                  2949
# coduf                         0
# codmun                     2263
# codRegiaoSaude             2949
# nomeRegiaoSaude            2949
# data                          0
# semanaEpi                     0
# populacaoTCU2019            686
# casosAcumulado                0
# casosNovos                    0
# obitosAcumulado               0
# obitosNovos                   0
# Recuperadosnovos         142755
# emAcompanhamentoNovos    142755
# dtype: int64

# %%
dados_covid_copia = dados_covid.copy()

# %%
dados_covid_copia['regiao'].unique
# Out:
# <bound method Series.unique of 0               Brasil
# 1               Brasil
# 2               Brasil
# 3               Brasil
# 4               Brasil
#               ...
# 142794    Centro-Oeste
# 142795    Centro-Oeste
# 142796    Centro-Oeste
# 142797    Centro-Oeste
# 142798    Centro-Oeste
# Name: regiao, Length: 142799, dtype: object>

# %%
#filtrar o dataframe
dados_covid_copia[dados_covid_copia['regiao'] == 'Nordeste'].head()
# Out:
#        regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 621  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 622  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 623  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 624  Nordeste     MA       NaN     21     NaN             NaN             NaN
# 625  Nordeste     MA       NaN     21     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 621  2020-03-21         12         7075181.0               1           0
# 622  2020-03-22         13         7075181.0               2           1
# 623  2020-03-23         13         7075181.0               2           0
# 624  2020-03-24         13         7075181.0               8           6
# 625  2020-03-25         13         7075181.0               8           0
#
# ...

# %%
#filtrar o dataframe por uma lista
lista = ['Nordeste', 'Sudeste']

dados_covid_copia[(dados_covid_copia['regiao'].isin(lista)) & (dados_covid_copia['codRegiaoSaude'].isnull())]
# Out:
#          regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 621    Nordeste     MA       NaN     21       NaN             NaN
# 622    Nordeste     MA       NaN     21       NaN             NaN
# 623    Nordeste     MA       NaN     21       NaN             NaN
# 624    Nordeste     MA       NaN     21       NaN             NaN
# 625    Nordeste     MA       NaN     21       NaN             NaN
# ...         ...    ...       ...    ...       ...             ...
# 87335   Sudeste     SP       NaN     35  350000.0             NaN
# 87336   Sudeste     SP       NaN     35  350000.0             NaN
# 87337   Sudeste     SP       NaN     35  350000.0             NaN
# 87338   Sudeste     SP       NaN     35  350000.0             NaN
# 87339   Sudeste     SP       NaN     35  350000.0             NaN
#
#       nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 621               NaN  2020-03-21         12         7075181.0
# ...

# %%
dados_covid_copia[dados_covid_copia['codRegiaoSaude'].isnull()]
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 138720  Centro-Oeste     GO       NaN     52  520000.0             NaN
# 138721  Centro-Oeste     GO       NaN     52  520000.0             NaN
# 138722  Centro-Oeste     GO       NaN     52  520000.0             NaN
# 138723  Centro-Oeste     GO       NaN     52  520000.0             NaN
# 138724  Centro-Oeste     GO       NaN     52  520000.0             NaN
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
#Assim como os arrays, você pode recuperar um valor especifico com uma série usando a notação de indexação [].
dados_covid_copia['casosAcumulado'][20]
# Out:
# 291

# %% [markdown]
# #EXERCICIOS

# %%
#Qual é o número total de casos relatados e mortes relacionadas ao Covid-19 no Brasil?
total_casos = dados_covid_copia.casosNovos.sum()
total_mortes = dados_covid_copia.obitosNovos.sum()

# %%
print('O numero de casos é {} e o numero de mortes é {}'.format(int(total_casos), int(total_mortes)))
# Out:
# O numero de casos é 1572762 e o numero de mortes é 90610

# %%
#Qual é a taxa geral de mortalidade (proporção de mortes relatadas para casos relatados)?
morte_rate = dados_covid_copia.obitosNovos.sum() / dados_covid_copia.casosNovos.sum()

# %%
print('A taxa de mortes do Brasil {:.2f} %'.format(morte_rate*100))
# Out:
# A taxa de mortes do Brasil 5.76 %

# %% [markdown]
# #Buscar os dias que tiveram mais de 1000 casos relatados. Podemos usar uma expressão booleana para verificar quais linhas atendem a esse critério.

# %%
mais_casos = dados_covid_copia.casosNovos > 1000
mais_casos
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 142794    False
# 142795    False
# 142796    False
# 142797    False
# 142798    False
# Name: casosNovos, Length: 142799, dtype: bool

# %%
dados_covid_copia[mais_casos]

# %%
#da para criar uma nova coluna
dados_covid_copia['taxa_morte'] = dados_covid_copia['obitosNovos'] / dados_covid_copia['casosNovos']

# %%
dados_covid_copia[['obitosNovos', 'casosNovos', 'taxa_morte']]

# %%
#Criar coluna nova

#essa taxa de morte, não é 100% devido ao tempo da doença e morte (remover)
dados_covid_copia.drop(columns=['taxa_morte'], inplace=True)

# %%
dados_covid_copia.columns

# %% [markdown]
# #Ordenar o dataframe

# %%
#maiores casos
dados_covid_copia.sort_values('casosNovos', ascending = False).head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-18568b757859> in <cell line: 0>()
#       1 #maiores casos
# ----> 2 dados_covid_copia.sort_values('casosNovos', ascending = False).head(5)
#
# NameError: name 'dados_covid_copia' is not defined

# %%
#maiores casos de morte
dados_covid_copia.sort_values('obitosNovos', ascending = False).head()

# %%
#Substituir dados
dados_covid.isna().sum()

# %%
#Remover registros null
dados_covid_copia.dropna()

# %%
#OUTROS

# %%
# Remover linhas que contenham pelo menos um valor nulo
df_sem_nulos_linha = df.dropna()


# Remover colunas que contenham pelo menos um valor nulo
df_sem_nulos_coluna = df.dropna(axis=1)


# Preencher valores nulos com um valor específico (por exemplo, zero)
df_preenchido_zero = df.fillna(0)


# Preencher valores nulos com uma string vazia
df_preenchido_vazio = df.fillna('')

# %%
#Remover linhas que contenham pelo menos um valor nulo
df_sem_nulos_linha = df.dropna()

#Remover colunas que contenham pelo menos um valor nulo
df_sem_nulos_coluna = df.dropna(axis=1)

# %%
#Preencher valores nulos com um valor específico (por exemplo, zero)
df_preenchido_zero = df.fillna(0)

#Preencher valores nulos com uma
df_preenchido_vazio = df.fillna('')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#Criando DATABASE do zero no colab

# %%
import numpy as np
import pandas as pd

exame = {'Nome': ['Manuela', 'Julio', 'Raul', 'Paulo'],
         'Nota': [12.5, np.nan, 9, 4.5],
         'Tentativas': [1, 1, 3, 2],
         'Passou': ['sim', 'não', 'sim', 'não']}

dt = pd.DataFrame(exame)
dt
# Out:
#       Nome  Nota  Tentativas Passou
# 0  Manuela  12.5           1    sim
# 1    Julio   NaN           1    não
# 2     Raul   9.0           3    sim
# 3    Paulo   4.5           2    não

# %%
dados_covid['a']

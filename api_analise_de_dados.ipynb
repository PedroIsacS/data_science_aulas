# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroIsacS/data_science_aulas/blob/main/api_analise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://publicapis.io/

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# Buscar informações de uma ação (exemplo: Apple)
acao = yf.Ticker("AAPL")

# Informações básicas sobre a ação
info_acao = pd.DataFrame([acao.info]) #convertendo informações em DataFrame

# %%
info_acao
# Out:
#              address1       city state    zip        country           phone  \
# 0  One Apple Park Way  Cupertino    CA  95014  United States  (408) 996-1010
#
#                  website              industry           industryKey  \
# 0  https://www.apple.com  Consumer Electronics  consumer-electronics
#
#            industryDisp  ... averageDailyVolume3Month fiftyTwoWeekLowChange  \
# 0  Consumer Electronics  ...                 50792552             83.020004
#
#   fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# 0                     0.505973    164.08 - 260.1                   -13.0
#
#   fiftyTwoWeekHighChangePercent  fiftyTwoWeekChangePercent  dividendDate  \
# 0                     -0.049981                  35.543167    1739404800
#
#    displayName  trailingPegRatio
# 0        Apple            2.2742
#
# [1 rows x 180 columns]

# %%
# Preço do histórico
historico = acao.history(period="1mo") # Ultimo mês

# %%
historico
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-01-27 00:00:00-05:00  223.773962  231.895022  223.733997  229.607544
# 2025-01-28 00:00:00-05:00  230.596471  239.926210  230.556507  237.998322
# 2025-01-29 00:00:00-05:00  233.862872  239.596573  233.752992  239.097122
# 2025-01-30 00:00:00-05:00  238.407871  240.525538  236.949483  237.329056
# 2025-01-31 00:00:00-05:00  246.918527  246.918527  233.183628  235.740814
# 2025-02-03 00:00:00-05:00  229.737419  231.575395  225.452122  227.759583
# 2025-02-04 00:00:00-05:00  227.000419  232.873966  226.401072  232.544327
# 2025-02-05 00:00:00-05:00  228.279016  232.414468  228.019307  232.214691
# 2025-02-06 00:00:00-05:00  231.035979  233.543232  230.176923  232.963867
# 2025-02-07 00:00:00-05:00  232.344548  233.743004  227.010401  227.380005
# 2025-02-10 00:00:00-05:00  229.570007  230.589996  227.199997  227.649994
# 2025-02-11 00:00:00-05:00  228.199997  235.229996  228.130005  232.619995
# ...

# %% [markdown]
# https://statusinvest.com.br/acoes/busca-avancada
